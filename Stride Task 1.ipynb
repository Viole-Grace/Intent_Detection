# %%
import re
import pandas as pd
import numpy as np
import regex as regex
import collections
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.cross_validation import train_test_split
from sklearn.svm import SVC
from sklearn import metrics
from nltk import ngrams
from stemming.porter2 import stem

# %%
#import dataset
raw_training_data, raw_testing_data = [],[]

with open("train.txt") as f:
    train=f.readlines()
    ttrain=f.read()
for item in train:
    raw_training_data.append(item.strip())
    
with open("test.txt") as f:
    test=f.readlines()
for item in test:
    raw_testing_data.append(item.strip())

# %%
#get an idea of the data
freq=pd.Series(' '.join(train[1]).split()).value_counts()[:10]
freq=list(freq.index)
wordcount = {}
# eliminate duplicates, split by punctuation and use case demiliters
for word in ttrain.lower().split('\t', 1):
    word = word.replace(".","")
    word = word.replace(",","")
    word = word.replace(":","")
    word = word.replace("\"","")
    word = word.replace("!","")
    word = word.replace("â€œ","")
    word = word.replace("â€˜","")
    word = word.replace("*","")
    if word not in wordcount:
        wordcount[word] = 1
    else:
        wordcount[word] += 1
#most common words / features
word_counter = collections.Counter(wordcount)
word_counter
# Out:
# Counter({'': 1})

# %%
#clean data

def clean(raw_data):
    
    #split into labels and text
    labels=[lab.split('\t', 1)[0] for lab in raw_data]
    training_data= [item.split('\t', 1)[1] for item in raw_data]
    
    labels,training_data
    
    #convert to lowercase, stem / lemmatize
    training_data = [i.lower() for i in training_data]
    training_data = [" ".join([stem(word) for word in sentence.split(" ")]) for sentence in training_data]
        
    #replace links, email_id, currencies, entities etc
    training_data=[re.sub(r'[\w\.-]+@[\w\.-]+', "$EMAIL_ID", i) for i in training_data]
    training_data=[re.sub(r"(<?)http:\S+", "$URL", i) for i in training_data]
    training_data=[re.sub(r"\$\d+", "$CURR", i) for i in training_data]
    training_data=[re.sub(r'\b\d+\b', "$NUM", i) for i in training_data]
    training_data=[re.sub(r'\b(me|her|him|us|them|you)\b', "$ENTITIES", i) for i in training_data]
    
    
    #remove punctuation, special chars, tokenize data
    training_data = [regex.sub(r"[^\P{P}$]+", " ", i) for i in training_data]
    training_data = [re.sub(r"[^0-9A-Za-z/$' ]", " ", i) for i in training_data]
    
    #regularize data w.r.t days, times, months and year
    regex_match_days= r'monday|tuesday|wednesday|thursday|friday|saturday|sunday'
    regex_match_times= r'morning|afternoon|evening'
    regex_match_events= r'after|before|during'
    regex_match_month= r'january|february|march|april|may|june|july|august|september|october|november|december'
    
    training_data = [re.sub(regex_match_days, "$day", i) for i in training_data]
    training_data = [re.sub(regex_match_times, "$times", i) for i in training_data]
    training_data = [re.sub(regex_match_events, "$events", i) for i in training_data]
    training_data = [re.sub(regex_match_month, "$month", i) for i in training_data]
    
    #remove extra spaces and blanks
    training_data = [item.strip() for item in training_data]
    
    #return cleaned data
    return training_data, labels

# %%
#n-gram based SVM Classification, since problem statement says its a binary Classification 
def get_phrases(text, n):
    
    """#define for 3 n-gram models : unigram, bigram and trigram.
    #bi_grams,tri_grams = "",""
    #bi_l,tri_l= [], []
    
    #get ngrams
    
    #bi_grams = ngrams(text.split(), 2)
    #tri_grams = ngrams(text.split(), 3)
    
    #build, set ngrams"""
    """for grams in bi_grams:
        bi_l.append('_'.join(map(str,grams)))
    for grams in tri_grams:
        tri_l.append('_'.join(map(str,grams)))    
    bstring= ' '.join(bi_l)
    tstring= ' '.join(tri_l)    
    return bstring,tstring"""
    
    n_grams=ngrams(text.split(),n)
    gram_list = []
    for grams in n_grams:
        gram_list.append('_'.join(map(str,grams)))
    gram_string = ' '.join(gram_list)
    print gram_string
    return gram_string

# %%
#the research paper attached makes use of TF-IDF, hence ranking constraints will be applied using TF-IDF
def tf_idf(data):
    
    vector_model= TfidfVectorizer(min_df=1) #single dataframe
    X = vector_model.fit_transform(data) #fit model and transform data to required vector
    
    #only one axis holds the ranking -> X axis
    return X

# %%
#get the cleaned data : 
training_data, training_labels = clean(raw_training_data)
testing_data, testing_labels = clean(raw_testing_data)

# since labels arent distributed in a random fashion, distribution is either a single set of 'NO' or 'NO' and 'YES' combined.
# get X,Y training data by mixing both, then using k-folds for distribution or check weight biases using jack-knife resampling
# another approach is to mix both data, then split using the train-test-split module.

X = tf_idf(training_data+testing_data)
Y = training_labels+testing_labels

#set random_state to 42 for reproducible results
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
#tune parameters for c and gamma, use the rbf kernel
#running the function takes time, so it has already been run once and best C and gammas have been identified
#best C for SVM model - 2100, 14,600, 23,200
def get_c_and_gamma(X,Y,nfolds):
    Cs = [0.0001, 0.001, 0.01, 0.1, 1, 10] #lower Cs value gives a simpler decision function
    gammas = [ 0.001, 0.01, 0.1, 1, 10] #inverse of radius of influence

    from sklearn.grid_search import GridSearchCV
    param_grid= {'C':Cs, 'gamma':gammas}
    grid_search = GridSearchCV(SVC(kernel='rbf'), param_grid, cv=nfolds)
    grid_search.fit(X, Y)
    print grid_search.best_params_
    return grid_search.best_params_
# Out:
# {'C': 1, 'gamma': 1}

# %%
#basic SVM model vs bi-gram model vs tri-gram model
#result classification can be seen using a confusion_matrix

#new_C=get_c_and_gamma(X,Y,10)
svm=SVC(C=2100, kernel = 'rbf')
svm.fit(x_train, y_train)
print "SVM classification : \n"
print "Training Accuracy : ",svm.score(x_train, y_train),"\nTesting Accuracy : ",svm.score(x_test, y_test)
# Out:
# SVM classification :
#
# Training Accuracy :  0.8850645359557467
# Testing Accuracy :  0.7813620071684588

# %%
#bi-gram and tri-gram SVM model
total_data = training_data+testing_data
total_labels = training_labels+testing_labels

bi_gram_data = [get_phrases(item,2) for item in total_data]
tri_gram_data = [get_phrases(item,3) for item in total_data]

X2, Y2 = tf_idf(bi_gram_data), total_labels
X3, Y3 = tf_idf(tri_gram_data), total_labels

x_train1, x_test1, y_train1, y_test1 = train_test_split(X2, Y2, test_size=0.3, random_state=42)
x_train2, x_test2, y_train2, y_test2 = train_test_split(X3, Y3, test_size=0.3, random_state=42)
# Out:
# $NUM_contact contact_$ENTITIES $ENTITIES_now now_to to_make make_$CURR $CURR_today today_$link
# act_now now_to to_keep keep_your your_life life_on on_the the_go
# choos_between between_$CURR $CURR_and and_$CURR $CURR_dollar dollar_with with_up up_to to_$NUM $NUM_year year_to to_repay
# click_abov abov_to to_earn earn_today
# click_here here_to to_receiv receiv_your your_first first_$CURR $CURR_today
# click_here here_to to_start start_shop shop_now now_$link
# click_here here_to to_watch watch_this this_now now_i i_m m_not not_sure sure_how how_long long_he he_ll ll_leav leav_this this_up up_in in_public
# confirm_now now_and and_view view_your your_first first_great great_opportun
# copi_and and_past past_this this_link link_into into_your your_browser browser_to to_see see_your your_result result_now
# find_out out_how how_to to_add add_clip clip_to to_your your_pressroom pressroom_in in_this this_$NUM $NUM_second second_video
# go_here here_now now_for for_direct direct_access
# go_here here_now now_for for_more more_inform
# if_$ENTITIES $ENTITIES_do do_not not_have have_adob adob_acrobat acrobat_reader reader_pleas pleas_click click_below below_and and_follow follow_instruct instruct_for for_free free_download download_$URL
# if_$ENTITIES $ENTITIES_do do_not not_want want_to to_confirm confirm_simpli simpli_ignor ignor_this this_message
# if_$ENTITIES $ENTITIES_don don_t t_want want_to to_chang chang_your your_password password_just just_ignor ignor_this this_message
# if_$ENTITIES $ENTITIES_see see_noth noth_or or_a a_banner banner_below below_pleas pleas_click click_here here_$URL $URL_notice notice_$ENTITIES $ENTITIES_are are_receiv receiv_this this_email email_becaus becaus_your your_email email_address address_was was_use use_to to_receiv receiv_an an_on on_lin lin_price price_quote quote_or or_becaus becaus_it it_was was_provid provid_with with_a a_vehicl vehicl_request
# if_$ENTITIES $ENTITIES_see see_noth noth_or or_a a_banner banner_below below_pleas pleas_click click_here here_$URL
# if_$ENTITIES $ENTITIES_want want_to to_see see_how how_i i_got got_out out_of of_debt debt_click click_the the_link link_below
# in_honor honor_of of_memori memori_day day_take take_advantag advantag_of of_this this_special special_deal
# in_honor honor_of of_mother mother_day day_take take_advantag advantag_of of_this this_huge huge_discount
# in_the the_event event_that that_he he_doe doe_phone phone_we we_would would_$NUM $NUM_like like_to to_make make_sure sure_that that_mr mr_lay lay_get get_this this_inform inform_prior prior_return return_the the_call
# join_now
# jude_search search_now now_and and_claim claim_today today_entry
# keep_move move_it it_forward
# open_glyder glyder_to to_get get_your your_feedback feedback_templat templat_it it_free free_for for_one one_week week_only
# or_mail mail_work work_now now_america america_at at_$NUM $NUM_somervill somervill_avenu avenu_suit suit_$NUM $NUM_somerville somerville_ma ma_$NUM
# over_and and_over over_again again_$ENTITIES $ENTITIES_tell tell_$ENTITIES $ENTITIES_how how_much much_plan plan_help help_$ENTITIES $ENTITIES_make make_god god_word word_a a_daili daili_part part_of of_your your_life
# pleas_add add_$EMAIL $EMAIL_ID ID_to to_your your_address address_book book_to to_ensur ensur_deliveri deliveri_to to_your your_inbox
# pleas_add add_mailto mailto_$EMAIL $EMAIL_ID ID_$EMAIL $EMAIL_ID ID_to to_your your_address address_book
# pleas_add add_to to_white white_list list_safe safe_sender sender_list
# pleas_add add_$ENTITIES $ENTITIES_to to_your your_contact
# pleas_$EMAIL $EMAIL_ID ID_to to_your your_address address_book book_to to_ensur ensur_deliveri deliveri_to to_your your_inbox
# pleas_go go_to to_the the_link link_below below_to to_regist regist_by by_verifi verifi_your your_email
# pleas_sign sign_in in_into into_the the_addappt addappt_app app_with with_your your_this this_particular particular_email email_and and_the the_invit invit_code code_provided
# pleas_use use_the the_link link_below below_to to_activ activ_your your_account
# run_heat heat_gener gener_applianc applianc_like like_oven oven_and and_dryer dryer_earli earli_in in_the the_morn morn_or or_late late_at at_night
# save_an an_extra extra_$CURR $CURR_on on_$NUM $NUM_night night_stay
# search_job job_now now_$link
# search_and and_appli appli_to to_job job_near near_$ENTITIES $ENTITIES_today
# send_$ENTITIES $ENTITIES_an an_email email_at at_$EMAIL $EMAIL_ID
# start_click click_here here_now now_if if_$ENTITIES $ENTITIES_want want_it it_$link
# start_save save_your your_money money_now now_and and_start start_clip clip_coupons
# stay_$NUM $NUM_night night_save save_$CURR
# stay_in in_the the_loop loop_here here_is is_a a_snapshot snapshot_of of_what what_go go_on on_in in_your your_pink pink_pad pad_group group_this this_week
# take_a a_few few_minut minut_out out_of of_your your_weekend weekend_to to_switch switch_accounts
# that_is is_whi whi_i i_am am_call call_on on_all all_$ENTITIES $ENTITIES_prayer prayer_warrior warrior_i i_need need_$ENTITIES $ENTITIES_to to_be be_in in_prayer prayer_with with_$ENTITIES $ENTITIES_this this_week
# to_ensur ensur_deliveri deliveri_to to_your your_inbox inbox_pleas pleas_add add_$EMAIL $EMAIL_ID
# to_ensur ensur_deliveri deliveri_to to_your your_inbox inbox_pleas pleas_add add_$EMAIL $EMAIL_ID
# to_ensur ensur_deliveri deliveri_to to_your your_inbox inbox_pleas pleas_add add_$EMAIL $EMAIL_ID
# to_ensur ensur_deliveri deliveri_to to_your your_inbox inbox_pleas pleas_add add_$EMAIL $EMAIL_ID ID_to to_your your_address address_book book_and and_safe safe_send send_list
# to_ensur ensur_deliveri deliveri_to to_your your_inbox inbox_pleas pleas_add add_$EMAIL $EMAIL_ID ID_to to_your your_address address_book book_and and_safe safe_send send_list
# to_ensur ensur_delivery delivery_pleas pleas_add add_$EMAIL $EMAIL_ID ID_to to_your your_address address_book
# to_ensur ensur_futur futur_deliveri deliveri_of of_email email_pleas pleas_add add_$EMAIL $EMAIL_ID ID_to to_your your_address address_book book_contact contact_or or_safe safe_sender sender_list
# to_ensur ensur_futur futur_deliveri deliveri_of of_emails emails_pleas pleas_add add_mailto mailto_$EMAIL $EMAIL_ID
# to_ensur ensur_our our_email email_are are_deliv deliv_to to_your your_inbox inbox_pleas pleas_add add_$ENTITIES $ENTITIES_to to_your your_contact contact_list
# to_ensur ensur_that that_$ENTITIES $ENTITIES_continu continu_receiv receiv_our our_emails emails_pleas pleas_add add_$ENTITIES $ENTITIES_to to_your your_address address_book book_or or_safe safe_list
# to_ensur ensur_that that_$ENTITIES $ENTITIES_continu continu_to to_receiv receiv_our our_emails emails_pleas pleas_add add_$EMAIL $EMAIL_ID ID_to to_your your_address address_book
# to_ensur ensur_that that_$ENTITIES $ENTITIES_keep keep_get get_all all_your your_email email_pleas pleas_add add_$EMAIL $EMAIL_ID
# to_ensur ensur_that that_$ENTITIES $ENTITIES_will will_receiv receiv_email email_from from_$ENTITIES $ENTITIES_pleas pleas_add add_$EMAIL $EMAIL_ID ID_to to_your your_address address_book
# to_ensur ensur_your your_email email_come come_to to_your your_inbox inbox_pleas pleas_add add_mailto mailto_$EMAIL $EMAIL_ID
# to_help help_$ENTITIES $ENTITIES_get get_to to_know know_$ENTITIES $ENTITIES_better better_we we_d d_like like_to to_tell tell_$ENTITIES $ENTITIES_more more_about about_membership membership_our our_partnership partnership_with with_parent parent_like like_$ENTITIES $ENTITIES_and and_the the_valu valu_we we_place place_on on_make make_a a_differ differ_in in_the the_world
# to_make make_sure sure_$ENTITIES $ENTITIES_receiv receiv_the the_most most_up up_to to_date date_deals deals_pleas pleas_add add_$EMAIL $EMAIL_ID ID_to to_your your_address address_book
# tri_$NUM $NUM_week week_free
# your_name name_compani compani_name name_and and_address address_state state_of of_incorporation incorporation_phone phone_and and_fax fax_number number_as as_well well_as as_an an_e e_mail mail_address address_if if_available available_should should_be be_includ includ_pleas pleas_print print_or or_type
# as_$ENTITIES $ENTITIES_recall recall_we we_had had_a a_veri veri_lengthi lengthi_discuss discuss_regard regard_the the_magnitud magnitud_of of_the the_work work_associ associ_with with_the the_hear hear_and and_associ associ_briefs
# doe_that that_mean mean_that that_$ENTITIES $ENTITIES_r r_final final_freed freed_from from_that that_hairball
# how_mani mani_hour hour_a a_night night_do do_$ENTITIES $ENTITIES_sleep
# i_will will_send send_an an_e e_mail mail_later later_in in_the the_day day_to to_see see_when when_we we_can can_get get_together
# if_$ENTITIES $ENTITIES_haven haven_t t_already already_pleas pleas_don don_t t_forget forget_to to_rate rate_$ENTITIES
# if_$ENTITIES $ENTITIES_need need_to to_chang chang_or or_cancel cancel_your your_appointment appointment_pleas pleas_do do_so so_at at_$link
# if_$ENTITIES $ENTITIES_read read_lessig lessig_piec piec_amp amp_agre agre_that that_research research_should should_have have_to to_disclos disclos_conflict conflict_of of_interest interest_pls pls_sign sign_petit petit_$link
# if_$ENTITIES $ENTITIES_swipe swipe_down down_a a_beauti beauti_wooden wooden_shelf shelf_will will_appear appear_a a_blue blue_tag tag_say say_tidi tidi_$ENTITIES $ENTITIES_which which_$ENTITIES $ENTITIES_should should_touch
# if_$ENTITIES $ENTITIES_wish wish_to to_not not_receiv receiv_further further_communic communic_via via_email email_from from_our our_compani compani_or or_would would_like like_to to_find find_out out_more more_about about_this this_sender sender_pleas pleas_updat updat_your your_profil profil_prefer prefer_$link
# if_$ENTITIES $ENTITIES_wish wish_to to_stop stop_futur futur_mailings mailings_pleas pleas_follow follow_here here_$link
# if_$ENTITIES $ENTITIES_would would_like like_to to_cancel cancel_or or_chang chang_your your_membership membership_options options_just just_visit visit_my my_account account_on on_rhapsody rhapsody_com
# if_$ENTITIES $ENTITIES_d d_like like_to to_disabl disabl_these these_notifications notifications_pleas pleas_visit visit_your your_profil profil_at at_$link
# if_$ENTITIES $ENTITIES_d d_like like_to to_no no_longer longer_receiv receiv_these these_emails emails_pleas pleas_follow follow_the the_instruct instruct_below
# if_$ENTITIES $ENTITIES_d d_like like_to to_receiv receiv_a a_coupon coupon_for for_$CURR $CURR_off off_your your_next next_purchas purchas_of of_$NUM $NUM_lbs lbs_or or_more more_pleas pleas_complet complet_the the_form
# if_$ENTITIES $ENTITIES_d d_like like_to to_turn turn_this this_off off_pleas pleas_visit visit_your your_appshopp appshopp_profil profil_to to_make make_chang chang_to to_your your_email
# if_$ENTITIES $ENTITIES_d d_like like_to to_view view_or or_chang chang_your your_account account_information information_pleas pleas_visit visit_$link
# if_$ENTITIES $ENTITIES_r r_interest interest_but but_aren aren_t t_one one_of of_the the_first first_$NUM $NUM_we we_will will_have have_plenti plenti_of of_other other_opportun opportun_to to_invit invit_$ENTITIES $ENTITIES_to to_join join_$ENTITIES $ENTITIES_throughout throughout_the the_year
# now_let let_$ENTITIES $ENTITIES_tell tell_$ENTITIES $ENTITIES_whi whi_this this_medallion medallion_and and_archangel archangel_michael michael_the the_most most_power power_of of_angels angels_can can_deliv deliv_the the_miracles miracles_protection protection_guidanc guidanc_and and_love love_$ENTITIES $ENTITIES_need need_to to_chang chang_your your_life life_so so_$ENTITIES $ENTITIES_can can_live live_your your_dreams
# pleas_answer answer_$ENTITIES $ENTITIES_$NUM $NUM_comment comment_$link
# pleas_keep keep_in in_mind mind_that that_if if_$ENTITIES $ENTITIES_have have_more more_than than_one one_video video_$ENTITIES $ENTITIES_ll ll_need need_to to_download download_each each_one one_separately
# pleas_tri tri_to to_delet delet_the the_applic applic_and and_instal instal_it it_again
# pleas_tri tri_to to_sign sign_up up_again again_at at_$link
# pronounc_jane jane_nee nee_but but_$ENTITIES $ENTITIES_can can_call call_$ENTITIES $ENTITIES_chickengirl
# she_put put_togeth togeth_a a_littl littl_someth someth_if if_$ENTITIES $ENTITIES_can can_use use_it it_fine fine_if if_not not_that that_fine fine_too
# talk_with with_$ENTITIES $ENTITIES_tonight
# tap_pet pet_hotel hotel_can can_$ENTITIES $ENTITIES_grow grow_your your_small small_kennel kennel_into into_a a_world world_class class_pet pet_hotel hotel_getaway
# the_issu issu_is is_a a_great great_exampl exampl_of of_the the_intersect intersect_of of_our our_busi busi_interest interest_with with_public public_polici polici_debat debat_and and_should should_promot promot_a a_live live_discuss discuss_when when_we we_get get_together
# the_onli onli_bad bad_thing thing_is is_they they_have have_to to_let let_$ENTITIES $ENTITIES_know know_tomorrow tomorrow_if if_they they_are are_interested
# the_recept recept_for for_paperkarma paperkarma_has has_been been_tremend tremend_and and_we we_r r_tri tri_to to_catch catch_up up_with with_the the_traffic traffic_we we_apolog apolog_for for_ani ani_delays
# they_have have_a a_big big_shop shop_and and_$ENTITIES $ENTITIES_should should_know know_some some_of of_the the_peopl peopl_there
# we_either either_need need_to to_have have_someon someon_ride ride_herd herd_on on_tozzini tozzini_on on_this this_i i_thought thought_it it_was was_jose jose_or or_i i_need need_to to_go go_to to_sp sp_and and_make make_this this_happen
# we_had had_some some_help help_discuss discuss_about about_assignment assignment_but but_i i_m m_not not_sure sure_how how_much much_progress progress_was was_made
# we_have have_our our_staff staff_meet meet_the the_1st 1st_and and_3rd 3rd_$day $day_at at_$NUM $NUM_i i_miss miss_the the_last last_one one_so so_i i_should should_make make_it it_to to_this this_one
# we_hope hope_$ENTITIES $ENTITIES_enjoy enjoy_omni omni_sync sync_server server_but but_pleas pleas_keep keep_in in_mind mind_that that_this this_is is_still still_in in_beta beta_and and_thing thing_$month $month_break break_the the_server server_$month $month_go go_down down_or or_your your_data data_$month $month_disappear
# we_want want_to to_welcom welcom_$ENTITIES $ENTITIES_to to_the the_horizon horizon_card card_servic servic_famili famili_of of_product product_and and_feel feel_confid confid_that that_$ENTITIES $ENTITIES_will will_soon soon_realiz realiz_the the_full full_benefit benefit_of of_this this_wise wise_credit credit_decis decis_as as_$ENTITIES $ENTITIES_join join_the the_thousand thousand_of of_other other_high high_satisfi satisfi_horizon horizon_gold gold_card card_privileg privileg_members
# we_will will_be be_in in_bay bay_citi citi_on on_$day $day_but but_i i_don don_t t_know know_if if_it it_will will_be be_overnight
# we_will will_have have_$NUM $NUM_for for_dinner dinner_not not_count count_the the_$NUM $NUM_year year_old old_who who_will will_have have_eaten eaten_although although_he he_will will_eat eat_a a_piec piec_of of_bread bread_if if_offered
# we_r r_go go_to to_have have_a a_legal legal_happi happi_hour hour_tomorrow tomorrow_at at_the the_blue blue_agave agave_and and_it it_would would_be be_no no_parti parti_without without_$ENTITIES $ENTITIES_there
# where_do do_$ENTITIES $ENTITIES_stand stand_on on_the the_individu individu_right right_of of_a a_smoker
# $ENTITIES_should should_also also_instal instal_the the_kicksend kicksend_iphon iphon_app app_which which_will will_let let_$ENTITIES $ENTITIES_send send_all all_the the_photo photo_and and_video video_$ENTITIES $ENTITIES_take take_instant instant_from from_your your_iphon iphon_to to_ani ani_email
# lose_everyth everyth_and and_go go_to to_prison prison_for for_$NUM $NUM_year year_or or_return return_to to_belfast belfast_to to_spi spi_on on_$ENTITIES $ENTITIES_own own_family
# nickyeven_if if_$ENTITIES $ENTITIES_alreadi alreadi_enjoy enjoy_read read_your your_bible bible_did did_$ENTITIES $ENTITIES_know know_that that_some some_of of_our our_most most_popular popular_bibles bibles_can can_also also_read read_to to_$ENTITIES $ENTITIES_listen listen_to to_the the_bibl bibl_let let_$ENTITIES $ENTITIES_experi experi_god god_word word_while while_$ENTITIES $ENTITIES_r r_do do_other other_things things_driving driving_exercising exercising_even even_read read_along
# convert_to to_instant instant_convert convert_email email_into into_appointments appointments_meetings meetings_memo memo_or or_tasks
# also_brent brent_would would_be be_in in_the the_best best_posit posit_to to_ensur ensur_that that_the the_logist logist_team team_meet meet_requir requir_for for_timeli timeli_and and_accuraci accuraci_of of_volumetr volumetr_inform inform_so so_that that_we we_can can_achiev achiev_our our_target target_headcount headcount_reduct reduct_in in_gas gas_oper oper_of of_$NUM $NUM_by by_year year_end end_$NUM
# also_for for_person person_over over_$NUM $NUM_who who_are are_sign sign_waivers waivers_we we_must must_provid provid_$ENTITIES $ENTITIES_with with_the the_census census_data data_about about_person person_under under_$NUM $NUM_over over_$NUM $NUM_who who_were were_offer offer_a a_package package_as as_well well_as as_their their_titl titl_and and_age
# becaus_of of_that that_i i_d d_like like_to to_ensur ensur_$ENTITIES $ENTITIES_that that_we we_will will_make make_everi everi_effort effort_to to_guid guid_$ENTITIES $ENTITIES_and and_answer answer_all all_your your_question question_about about_mobil mobil_publishing
# befor_$ENTITIES $ENTITIES_can can_use use_truffles truffles_$ENTITIES $ENTITIES_must must_gentl gentl_clean clean_it it_from from_the the_ground ground_with with_a a_soft soft_brush brush_in in_order order_to to_elimin elimin_all all_the the_ground ground_particles
# but_what what_doe doe_brand brand_build build_consist consist_of of_and and_how how_do do_$ENTITIES $ENTITIES_go go_about about_do do_it it_effect effect_and and_efficiently
# confer_call call_will will_be be_available
# final_though though_we we_can can_burst burst_and and_shout shout_it it_from from_the the_rooftop
# happi_birthday birthday_what what_did did_$ENTITIES $ENTITIES_get
# hello_my my_dear dear_my my_name name_is is_cynthia cynthia_i i_read read_your your_inform inform_on on_face face_book book_and and_find find_it it_truli truli_interest interest_that that_is is_whi whi_i i_am am_contact contact_$ENTITIES $ENTITIES_so so_that that_we we_can can_get get_to to_know know_each each_other other_better better_for for_person person_relationship relationship_besid besid_i i_have have_a a_special special_issu issu_to to_discuss discuss_with with_$ENTITIES $ENTITIES_on on_a a_veri veri_serious serious_note note_i i_hope hope_to to_hear hear_from from_$ENTITIES $ENTITIES_soon
# hey_$ENTITIES $ENTITIES_should should_see see_$ENTITIES $ENTITIES_up up_here
# hope_we we_can can_find find_a a_simpler simpler_approach approach_but but_i i_don don_t t_see see_ani ani_inher inher_problem problem_with with_someth someth_like like_that that_if if_it it_seem seem_to to_make make_the the_most most_financi financi_sense
# i_am am_current current_a a_junior junior_year year_histori histori_student student_at at_occident occident_colleg colleg_in in_los los_angeles angeles_but but_i i_will will_be be_in in_the the_bay bay_area area_all all_summer
# i_have have_alreadi alreadi_given given_$ENTITIES $ENTITIES_a a_head head_up up_on on_the the_valu valu_at at_stake stake_if if_we we_can can_come come_in in_at at_the the_low low_end end_of of_the the_scale scale_and and_early
# i_have have_ask ask_dan dan_lyon lyon_to to_give give_$ENTITIES $ENTITIES_a a_call call_on on_this
# i_have have_ask ask_my my_assist assist_patti patti_to to_help help_$ENTITIES $ENTITIES_in in_set set_up up_meet meet_for for_next next_week week_and and_i i_had had_ask ask_$ENTITIES $ENTITIES_to to_arrang arrang_a a_lunch lunch_with with_$ENTITIES $ENTITIES_and and_brent brent_plus plus_some some_time time_for for_just just_the the_two two_of of_$ENTITIES $ENTITIES_to to_get get_together
# i_was was_go go_to to_forward forward_the the_same same_thing thing_to to_$ENTITIES $ENTITIES_yesterday yesterday_but but_didn didn_t t_want want_$ENTITIES $ENTITIES_to to_think think_i i_was was_an an_asshole
# i_would would_like like_to to_see see_it it_but but_i i_bet bet_it it_take take_a a_while while_to to_get get_the the_support
# i_would would_like like_to to_welcom welcom_hillaryclinton hillaryclinton_the the_futur futur_$ENTITIES $ENTITIES_know know_what what_to to_twitter
# i_would would_love love_to to_be be_there there_but but_unfortun unfortun_i i_can can_t t_make make_it
# i_ll ll_get get_with with_$ENTITIES $ENTITIES_on on_$day
# i_ll ll_give give_$ENTITIES $ENTITIES_the the_detail detail_as as_i i_confirm confirm_my my_situat situat_with with_the the_portland portland_trip
# i_m m_go go_to to_tri tri_to to_make make_the the_$day $day_$NUM $NUM_00pm 00pm_appointment
# if_i i_can can_get get_steve steve_assign assign_finish finish_quickly quickly_i i_will will_turn turn_my my_attent attent_back back_to to_this
# if_$ENTITIES $ENTITIES_continu continu_to to_use use_our our_servic servic_$events $events_juli juli_$NUM $NUM_$NUM $NUM_$ENTITIES $ENTITIES_agre agre_to to_the the_updat updat_term term_or or_if if_$ENTITIES $ENTITIES_don don_t t_agree agree_$ENTITIES $ENTITIES_can can_cancel cancel_your your_servic servic_at at_ani ani_time
# if_$ENTITIES $ENTITIES_don don_t t_know know_$ENTITIES $ENTITIES_they they_were were_probabl probabl_just just_impress impress_with with_your your_review review_and and_didn didn_t t_want want_to to_miss miss_ani ani_of of_your your_app app_activity
# if_$ENTITIES $ENTITIES_don don_t t_see see_the the_highlight highlight_view view_yet yet_$ENTITIES $ENTITIES_can can_expect expect_to to_see see_it it_veri veri_soon soon_as as_we we_roll roll_out out_the the_featur featur_to to_everyone
# if_$ENTITIES $ENTITIES_don don_t t_think think_$ENTITIES $ENTITIES_ll ll_have have_your your_book book_finish finish_in in_time time_we we_don don_t t_want want_$ENTITIES $ENTITIES_to to_miss miss_out out_on on_this this_fantast fantast_sale sale_so so_until until_$NUM $NUM_$month $month_$NUM $NUM_$ENTITIES $ENTITIES_can can_purchas purchas_one one_of of_our our_gift gift_voucher voucher_at at_$NUM $NUM_off
# if_$ENTITIES $ENTITIES_don don_t t_want want_the the_govern govern_to to_get get_your your_$ $_interest interest_free free_but but_are are_awar awar_that that_$ENTITIES $ENTITIES_$month $month_owe owe_$ $_later later_on on_$month $month_15th 15th_then then_claim claim_a a_higher higher_number number_of of_depend depend_and and_marri marri_and and_jointly
# if_$ENTITIES $ENTITIES_don don_t t_have have_enough enough_transact transact_histori histori_built built_up up_in in_your your_hellowallet hellowallet_account account_at at_this this_time time_don don_t t_worry worry_there there_are are_still still_plenti plenti_of of_way way_we we_can can_help help_this this_year year_and and_by by_this this_time time_next next_year year_$ENTITIES $ENTITIES_ll ll_have have_enough enough_histori histori_to to_review
# if_$ENTITIES $ENTITIES_would would_like like_to to_chang chang_your your_e e_mail mail_address address_then then_log log_on on_to to_pogo pogo_com com_and and_updat updat_your your_account account_information
# instead_i i_want want_to to_meet meet_with with_frank frank_vicker vicker_and and_ed ed_baughman baughman_i i_have have_known known_both both_for for_year year_and and_we we_get get_both both_gas gas_and and_power power_covered covered_either either_$day $day_$times $times_or or_$day $day_to to_go go_over over_the the_present present_in in_person person_and and_get get_their their_thought thought_and and_input input_rahil rahil_included
# later_if if_$ENTITIES $ENTITIES_do do_decid decid_to to_tri tri_again again_work work_close close_with with_your your_health health_care care_provid provid_to to_lower lower_the the_risks
# my_word word_as as_a a_christian christian_man man_is is_to to_util util_the the_$NUM $NUM_$NUM $NUM_million million_dollar dollar_that that_$ENTITIES $ENTITIES_will will_donat donat_to to_$ENTITIES $ENTITIES_toward toward_the the_church church_and and_if if_$ENTITIES $ENTITIES_allow allow_$ENTITIES $ENTITIES_i i_have have_anoth anoth_church church_in in_mind mind_that that_i i_will will_like like_to to_donat donat_to
# normal_we we_would would_like like_to to_come come_in in_for for_an an_introduct introduct_meet meet_$NUM $NUM_$NUM $NUM_$NUM $NUM_hours hours_to to_get get_the the_basic basic_concept concept_cover cover_and and_then then_talk talk_about about_what what_our our_e e_risk risk_practic practic_does
# notic_that that_i i_m m_not not_volunt volunt_to to_make make_that that_phone phone_call
# on_decemb decemb_7th 7th_we we_would would_like like_to to_rememb rememb_and and_honor honor_the the_brave brave_men men_and and_women women_who who_lost lost_their their_live live_in in_the the_attack attack_at at_pearl pearl_harbor
# sinc_there there_are are_at at_least least_$NUM $NUM_sbeck sbeck_here here_have have_$ENTITIES $ENTITIES_thought thought_about about_adopt adopt_use use_of of_your your_long long_name name_address address_rather rather_than than_the the_shorter shorter_version version_to to_help help_in in_further further_differenti differenti_between between_$ENTITIES
# so_now now_$ENTITIES $ENTITIES_don don_t t_have have_to to_go go_dig dig_around around_for for_a a_comment comment_when when_$ENTITIES $ENTITIES_r r_on on_a a_client client_call
# sorri_about about_the the_long long_wind wind_voic voic_mail
# specifically_we we_are are_look look_for for_name name_and and_address address_of of_the the_following
# sure_to to_pleas pleas_even even_those those_who who_shi shi_away away_from from_most most_mod mod_decor
# tana_will will_attend
# the_latest latest_gadgets gadgets_buy buy_now now_or or_wait
# the_sens sens_of of_urgenc urgenc_for for_get get_this this_in in_the the_mix mix_is is_not not_as as_high high_as as_it it_was was_yesterday yesterday_though though_we we_ll ll_still still_need need_to to_introduc introduc_it it_at at_some some_point point_veri veri_soon
# the_sens sens_of of_urgenc urgenc_for for_get get_this this_in in_the the_mix mix_is is_not not_as as_high high_as as_it it_was was_yesterday yesterday_though though_we we_ll ll_still still_need need_to to_introduc introduc_it it_at at_some some_point point_veri veri_soon
# these_fund fund_can can_be be_deposit deposit_direct direct_into into_your your_account account_withno withno_financi financi_or or_employ employ_verif verif_by by_tomorrow
# this_is is_remind remind_that that_your your_free free_$NUM $NUM_day day_trial trial_will will_come come_to to_an an_end end_in in_$NUM $NUM_days
# timeless_piec piec_$ENTITIES $ENTITIES_ll ll_enjoy enjoy_now now_and and_for for_year year_to to_come
# we_can can_make make_it it_easi easi_for for_$ENTITIES
# we_can can_make make_this this_work work_either either_way
# we_can can_ship ship_to to_$ENTITIES $ENTITIES_or or_your your_grad
# we_should should_cast cast_a a_littl littl_broader broader_net net_on on_this this_internally internally_yoder yoder_calger calger_belden belden_foster foster_sanders sanders_etc etc_but but_seem seem_that that_given given_the the_governor governor_action action_as as_of of_late late_the the_likelihood likelihood_of of_nonpay nonpay_might might_even even_be be_a a_bit bit_higher higher_than than_$NUM
# we_stop stop_by by_to to_see see_kirk kirk_and and_sue sue_and and_i i_had had_$ENTITIES $ENTITIES_give give_jerri jerri_a a_call call_on on_the the_phone
# we_want want_to to_reward reward_$ENTITIES $ENTITIES_for for_do do_what what_$ENTITIES $ENTITIES_love
# we_want want_to to_take take_this this_opportun opportun_to to_highlight highlight_some some_of of_the the_key key_chang chang_and and_what what_they they_mean mean_for for_$ENTITIES
# we_will will_also also_be be_discuss discuss_suggest suggest_promot promot_dure dure_this this_meet meet_as as_well
# we_will will_updat updat_both both_schedul schedul_in in_the the_futur futur_for for_all all_deal deal_origin origin_whether whether_valu valu_was was_origin origin_or or_not
# we_will will_updat updat_tomorrow
# we_ll ll_have have_to to_wait wait_til til_mark mark_greenberg greenberg_get get_in in_tomorrow
# we_ll ll_see see_$ENTITIES $ENTITIES_tomorrow
# what_time time_do do_$ENTITIES $ENTITIES_get get_home home_from from_school
# what_why why_who who_are are_$ENTITIES $ENTITIES_proudtolove
# when_$ENTITIES $ENTITIES_sow sow_a a_$CURR $CURR_faith faith_seed seed_let let_$ENTITIES $ENTITIES_tell tell_$ENTITIES $ENTITIES_what what_i i_am am_go go_to to_do do_i i_will will_place place_your your_name name_in in_my my_bibl bibl_for for_the the_next next_year
# with_textfre textfre_$ENTITIES $ENTITIES_get get_free free_unlimit unlimit_text text_and and_pics pics_plus plus_make make_phone phone_calls
# with_a a_small small_group group_your your_talk talk_can can_be be_inform inform_and and_$ENTITIES $ENTITIES_do do_not not_need need_to to_prepar prepar_slide slide_unless unless_$ENTITIES $ENTITIES_would would_like like_to to_do do_so
# with_the the_energi energi_crisi crisi_in in_california california_at at_this this_time time_we we_will will_need need_to to_be be_extra extra_care care_with with_nomin nomin_at at_socal socal_and and_throughout throughout_the the_west west_to to_ensur ensur_that that_we we_continu continu_to to_provid provid_the the_excel excel_nomin nomin_servic servic_that that_we we_have have_been been_provid provid_to to_our our_customers
# $ENTITIES_deserv deserv_to to_have have_a a_happi happi_$day $day_$times $times_and and_we we_hope hope_this this_$CURR $CURR_walgreen walgreen_card card_can can_make make_that that_happen
# $ENTITIES_don don_t t_have have_to to_take take_a a_day day_off off_to to_attend attend_workshops
# the_codnapp codnapp_and and_his his_team team_of of_associ associ_rescu rescu_unsuspect unsuspect_fan fan_from from_their their_ldquo ldquo_to to_do do_rdquo rdquo_list list_and and_everyday everyday_chore chore_and and_deliv deliv_$ENTITIES $ENTITIES_to to_an an_oasi oasi_known known_as as_onslaught onslaught_the the_first first_download download_content content_pack pack_avail avail_for for_call call_of of_duty duty_ghosts
# there_a a_meet meet_with with_a a_cast cast_of of_charact charact_to to_discuss discuss_the the_westinhous westinhous_warranti warranti_issues
# let_$ENTITIES $ENTITIES_help help_$ENTITIES $ENTITIES_find find_the the_right right_health health_insur insur_plan plan_for for_$ENTITIES $ENTITIES_and and_your your_family
# however_if if_$ENTITIES $ENTITIES_want want_to to_follow follow_cheryl cheryl_s s_click click_the the_link link_below below_to to_go go_to to_their their_profil profil_to to_follow follow_$ENTITIES $ENTITIES_back
# if_$ENTITIES $ENTITIES_would would_like like_to to_be be_taken taken_off off_of of_all all_futur futur_mail mail_from from_santand santand_with with_one one_click
# u_can can_hit hit_$ENTITIES $ENTITIES_u u_later later_on on_if if_u u_wanna
# $ENTITIES_have have_help help_option option_if if_$ENTITIES $ENTITIES_d d_like like_to to_postpon postpon_your your_student student_loan loan_payment payment_for for_$NUM $NUM_months
# the_lord lord_told told_$ENTITIES $ENTITIES_that that_my my_$NUM $NUM_closest closest_friend friend_and and_partner partner_who who_respond respond_first first_are are_go go_to to_experi experi_this this_uniqu uniqu_$NUM $NUM_day day_miracle
# whether_$ENTITIES $ENTITIES_r r_on on_your your_desktop desktop_your your_mobil mobil_device device_or or_your your_tablet tablet_unroll unroll_m m_is is_there there_for for_$ENTITIES $ENTITIES_with with_our our_new new_respons respons_design
# the_sender sender_and and_subject subject_tab tab_let let_$ENTITIES $ENTITIES_quick quick_act act_on on_batch batch_of of_relat relat_email
# if_$ENTITIES $ENTITIES_would would_like like_to to_download download_the the_spotcha
# so_much much_happen happen_on on_twitter twitter_everi everi_day day_whether whether_it it_break break_news news_a a_deal deal_at at_your your_favorit favorit_shop shop_a a_local local_traffic traffic_jam jam_or or_a a_funni funni_pick pick_$ENTITIES $ENTITIES_up up_from from_a a_friend
# $ENTITIES_not not_email email_$ENTITIES
# how_much much_will will_your your_donat donat_cost cost_$ENTITIES
# so_especi especi_given given_the the_post post_$NUM $NUM_$NUM $NUM_logistics logistics_it it_doesn doesn_t t_seem seem_practic practic_for for_$ENTITIES $ENTITIES_to to_come come_to to_dalla dalla_for for_this this_meeting
# i_think think_that that_move move_forward forward_in in_my my_new new_job job_will will_not not_allow allow_$ENTITIES $ENTITIES_the the_time time_to to_continu continu_our our_sessions
# whi_won won_t t_they they_let let_$ENTITIES $ENTITIES_go go_to to_the the_corp corp_conference
# so_rather rather_than than_discuss discuss_the the_transition transition_kevin kevin_had had_to to_react react_to to_and and_absorb absorb_this this_as as_a a_possibility
# sean_paid paid_$ENTITIES $ENTITIES_for for_his his_and and_molli molli_dinner dinner_and and_eldon eldon_and and_nanci nanci_will will_pay pay_$ENTITIES $ENTITIES_for for_theirs
# let_$ENTITIES $ENTITIES_give give_$ENTITIES $ENTITIES_one one_less less_thing thing_to to_worri worri_about
# $ENTITIES_can can_go go_through through_the the_prompt prompt_if if_$ENTITIES $ENTITIES_would would_like like_to to_take take_this this_bonus
# everyth_given given_to to_$ENTITIES $ENTITIES_for for_$ENTITIES $ENTITIES_guy guy_was was_actual actual_wholesal wholesal_stuff
# i_ll ll_forward forward_$ENTITIES $ENTITIES_a a_note note_from from_sue sue_to to_rosi rosi_and and_$ENTITIES $ENTITIES_that that_$ENTITIES $ENTITIES_weren weren_t t_on
# read_$ENTITIES $ENTITIES_four four_social social_media media_site site_for for_bookworm
# the_sort sort_of of_pick pick_$ENTITIES $ENTITIES_up up_everi everi_sofa sofa_bed bed_and and_chais chais_need need_right right_around around_now
# hurri_below below_and and_choos choos_a a_reward reward_$ENTITIES $ENTITIES_d d_like like_to to_earn
# if_$ENTITIES $ENTITIES_would would_like like_to to_opt opt_in in_click click_the the_link link_below
# ignor_$ENTITIES $ENTITIES_onc onc_and and_i i_ll ll_ignor ignor_$ENTITIES $ENTITIES_forev forev_bye
# i_am am_copi copi_$ENTITIES $ENTITIES_on on_this this_email email_so so_that that_if if_i i_am am_mistaken mistaken_she she_can can_let let_$ENTITIES $ENTITIES_know
# $ENTITIES_can can_use use_line line_both both_on on_iphon iphon_and and_androids androids_download download_it it_from from_here here_and and_add add_$ENTITIES $ENTITIES_as as_a a_friend
# well_let let_$ENTITIES $ENTITIES_tell tell_$ENTITIES
# and_if if_$ENTITIES $ENTITIES_tri tri_to to_tell tell_$ENTITIES $ENTITIES_coffe coffe_isn isn_t t_healthi healthi_i i_will will_call call_$ENTITIES $ENTITIES_a a_fuck fuck_communist
# help_$ENTITIES $ENTITIES_help help_$ENTITIES
# let_$ENTITIES $ENTITIES_just just_download download_the the_new new_app
# let_$ENTITIES $ENTITIES_sum sum_this this_up up_real real_quick
# will_she she_buy buy_$ENTITIES $ENTITIES_some some_toy toy_a a_motorcycle motorcycle_let let_$ENTITIES $ENTITIES_get get_my my_fli fli_licenses licenses_and and_a a_cheaper cheaper_$NUM $NUM_wheel wheel_drive drive_vehicle
# call_$ENTITIES $ENTITIES_$monthbe $monthbe_militari militari_version version_ericraum ericraum_juli juli_$NUM $NUM_$NUM $NUM_$link
# dr_tomorrow tomorrow_mi mi_name name_for for_a a_girl girl_can can_$ENTITIES $ENTITIES_help help_$ENTITIES $ENTITIES_$NUM $NUM_vote vote_$link
# hey_call call_$ENTITIES $ENTITIES_brothers
# if_$ENTITIES $ENTITIES_enjoy enjoy_our our_app app_and and_want want_to to_help help_$ENTITIES $ENTITIES_to to_continu continu_to to_improv improv_our our_products products_pleas pleas_leav leav_$ENTITIES $ENTITIES_a a_good good_review review_on on_the the_app app_store store_n n_nenjoy nenjoy_and and_happi happi_collecting collecting_n n_nethan nethan_c c_allen allen_nsort nsort_it it_apps apps_llc llc_founder founder_n n_nif nif_$ENTITIES $ENTITIES_don don_t t_want want_to to_hear hear_from from_$ENTITIES $ENTITIES_anymore anymore_just just_go go_here here_$link
# let_$ENTITIES $ENTITIES_call call_$ENTITIES
# this_might might_be be_one one_of of_those those_let let_$ENTITIES $ENTITIES_get get_alan alan_to to_help help_$ENTITIES $ENTITIES_for for_a a_free free_lunch lunch_things
# call_$ENTITIES $ENTITIES_crazi crazi_$NUM $NUM_comment comment_$link
# pleas_follow follow_$ENTITIES
# and_if if_$ENTITIES $ENTITIES_d d_like like_$ENTITIES $ENTITIES_to to_answer answer_your your_question question_on on_a a_video video_or or_podcast podcast_pleas pleas_fill fill_out out_this this_short short_survey
# $NUM_we we_are are_just just_get get_ramp ramp_up up_so so_pleas pleas_bear bear_with with_$ENTITIES
# lilbthebasedgod_pleas pleas_tell tell_$ENTITIES $ENTITIES_whi whi_lil lil_b b_soooooo soooooo_raw
# actually_$ENTITIES $ENTITIES_could could_set set_the the_prioriti prioriti_for for_$ENTITIES
# am_i i_go go_to to_get get_an an_eye eye_infect infect_if if_i i_continu continu_to to_wear wear_your your_sunglass sunglass_around around_town
# as_well well_to to_reduc reduc_the the_conflict conflict_between between_the the_trade trade_and and_origin origin_organ organ_in in_order order_to to_keep keep_$ENTITIES $ENTITIES_spend spend_more more_time time_in in_the the_market market_than than_focus focus_on on_intern intern_issues
# attach_pleas pleas_find find_the the_modifi modifi_transact transact_agreement agreement_which which_has has_been been_revis revis_to to_reflect reflect_the the_matter matter_$ENTITIES $ENTITIES_discuss discuss_earlier earlier_today
# best_place place_to to_stay stay_given given_where where_$ENTITIES $ENTITIES_need need_to to_be be_but but_sometim sometim_a a_bit bit_difficult difficult_to to_get get_in in_to to_is is_the the_park park_hyatt
# both_test test_came came_back back_abnorm abnorm_and and_i i_am am_see see_a a_specialist specialist_this this_week week_to to_determin determin_if if_i i_need need_to to_have have_a a_biopsi biopsi_or or_not
# but_i i_would would_like like_to to_go go_out out_on on_what what_u u_might might_say say_a a_date date_when when_i i_get get_back
# but_$ENTITIES $ENTITIES_have have_to to_search search_now now_to to_let let_$ENTITIES $ENTITIES_know know_$ENTITIES $ENTITIES_want want_to to_win win_this this_amaz amaz_vehicl vehicl_worth worth_over over_$CURR $CURR_ooo ooo_oo
# calif_gop gop_lawmak lawmak_ask ask_puc puc_presid presid_to to_resign resign_updated updated_$day $day_$month $month_$NUM $NUM_$NUM $NUM_$NUM $NUM_$NUM $NUM_pm pm_et
# confer_room room_set set_up up_for for_compani compani_annual annual_meet
# do_$ENTITIES $ENTITIES_want want_to to_help help_people
# do_$ENTITIES $ENTITIES_want want_to to_make make_a a_difference
# doe_1pm 1pm_west west_coast coast_time time_work work_for for_folk folk_to to_have have_a a_brief brief_kick kick_off off_discuss discuss_of of_how how_we we_might might_assess assess_the the_cost cost_of of_a a_california california_for for_californian californian_energi energi_policy
# give_21st 21st_centuri centuri_auto auto_insur insur_a a_call call_at at_$NUM $NUM_$NUM $NUM_$NUM $NUM_we we_ll ll_tri tri_to to_lower lower_your your_quot quot_even even_more more_by by_see see_if if_$ENTITIES $ENTITIES_qualifi qualifi_for for_addit addit_discounts
# go_get get_em em_tiger
# hannah_certain certain_event event_in in_our our_live live_should should_give give_$ENTITIES $ENTITIES_reason reason_to to_pause pause_on on_these these_moments moments_consid consid_the the_protect protect_$ENTITIES $ENTITIES_could could_get get_through through_life life_insurance
# he_didn didn_t t_get get_it it_and and_we we_need need_to to_get get_that that_fix fix_asap
# how_do do_$ENTITIES $ENTITIES_make make_those those_ham ham_and and_tortillia tortillia_thingys
# how_would would_$ENTITIES $ENTITIES_spend spend_this this_$NUM $NUM_dollar dollar_onc onc_it it_in in_your your_hands
# i_am am_go go_to to_get get_fuck fuck_on on_broker broker_gift gift_this this_x x_mas
# i_am am_go go_to to_get get_much much_closer closer_to to_the the_model model_this this_time time_than than_last last_becaus becaus_of of_the the_turnov turnov_due due_to to_robert robert_and and_joana joana_move move_on
# i_am am_write write_to to_each each_of of_$ENTITIES $ENTITIES_becaus becaus_i i_need need_$ENTITIES $ENTITIES_to to_be be_in in_prayer prayer_with with_$ENTITIES $ENTITIES_this this_week
# i_haven haven_t t_met met_kevin kevin_yet yet_so so_if if_$ENTITIES $ENTITIES_could could_mention mention_this this_to to_$ENTITIES $ENTITIES_i i_would would_appreci appreci_it
# i_haven haven_t t_play play_softbal softbal_in in_a a_long long_time time_and and_this this_is is_a a_good good_way way_for for_$ENTITIES $ENTITIES_to to_get get_to to_know know_the the_peopl peopl_that that_i i_work work_with
# i_hope hope_$ENTITIES $ENTITIES_can can_help help_we we_look look_forward forward_to to_arrang arrang_your your_live live_training training_and and_receiv receiv_ani ani_great great_photo photo_$ENTITIES $ENTITIES_want want_to to_send
# i_just just_want want_to to_make make_sure sure_that that_rosi rosi_doesn doesn_t t_get get_all all_cross cross_up up_with with_mani mani_of of_$ENTITIES $ENTITIES_send send_$ENTITIES $ENTITIES_stuff
# i_must must_reiter reiter_to to_all all_member member_that that_i i_certain certain_don don_t t_like like_to to_hear hear_this this_even even_from from_one one_singl singl_member member_therefor therefor_i i_have have_decid decid_to to_hold hold_a a_live live_train train_event
# i_plan plan_to to_get get_off off_4pm 4pm_and and_check check_in in_the the_hotel hotel_a a_s s_a a_p
# i_want want_to to_get get_lee lee_into into_this this_also
# i_want want_to to_get get_a a_feel feel_for for_what what_we we_have have_done done_and and_set set_some some_goal goal_as as_to to_what what_need need_to to_be be_done
# i_want want_to to_make make_sure sure_i i_m m_do do_everyth everyth_i i_can can_to to_help help_$ENTITIES
# i_want want_to to_make make_sure sure_we we_have have_cover cover_all all_of of_the the_counterparties
# i_was was_wonder wonder_whi whi_i i_wasn wasn_t t_get get_ani ani_mail
# i_will will_call call_isda isda_and and_tri tri_to to_get get_a a_read read_on on_what what_isda isda_want want_to to_do do_which which_is is_not not_clear clear_at at_this this_point
# i_would would_like like_to to_get get_that that_from from_vng
# i_d d_like like_to to_get get_as as_divers divers_a a_group group_of of_co co_sponsor sponsor_as as_possible possible_and and_as as_mani mani_as as_possible
# i_d d_like like_to to_get get_that that_avail avail_for for_my my_trip trip_to to_houston houston_next next_wk
# i_ll ll_call call_$ENTITIES $ENTITIES_tomorrow
# i_m m_avail avail_at at_$NUM $NUM_am am_do do_while while_$ENTITIES $ENTITIES_r r_driving driving_and and_will will_make make_my my_schedul schedul_flexibl flexibl_in in_the the_$times
# i_m m_read read_this this_story story_i i_think think_$ENTITIES $ENTITIES_would would_like like_it
# i_m m_write write_to to_appli appli_for for_the the_market market_internship internship_at at_bookvibe
# i_v v_alway alway_want want_to to_work work_with with_book book_and and_around around_the the_publish publish_process process_and and_i i_would would_love love_to to_have have_some some_experi experi_in in_the the_field
# if_the the_enclos enclos_meet meet_with with_your your_approval approval_pleas pleas_have have_the the_agreement agreement_execut execut_and and_return return_a a_copi copi_to to_$ENTITIES $ENTITIES_via via_fax fax_no
# if_$ENTITIES $ENTITIES_can can_add add_this this_featur featur_i i_promis promis_to to_give give_this this_app app_a a_$NUM
# if_$ENTITIES $ENTITIES_can can_interview interview_well well_and and_prepar prepar_for for_the the_onsloaught onsloaught_of of_question question_and and_inquiri inquiri_$ENTITIES $ENTITIES_$month $month_be be_abl abl_to to_land land_the the_job
# if_$ENTITIES $ENTITIES_creat creat_$ENTITIES $ENTITIES_all all_on on_page page_$NUM $NUM_all all_will will_point point_to to_page page_$NUM $NUM_tri tri_to to_go go_to to_page page_$NUM $NUM_creat creat_one one_and and_then then_go go_to to_page page_$NUM $NUM_creat creat_one
# if_$ENTITIES $ENTITIES_do do_encount encount_work work_via via_email email_or or_are are_face face_with with_ani ani_work work_at at_all all_then then_to to_purg purg_the the_virus virus_send send_an an_email email_to to_your your_boss boss_with with_the the_word word_i i_v v_had had_enough enough_of of_your your_crap crap_i i_m m_off off_to to_the the_bar
# if_$ENTITIES $ENTITIES_download download_ani ani_of of_these these_version version_to to_your your_device device_$ENTITIES $ENTITIES_ll ll_be be_abl abl_to to_read read_it it_anytime anytime_anywhere anywhere_even even_when when_$ENTITIES $ENTITIES_can can_t t_connect connect_to to_your your_servic servic_provid provid_or or_to to_the the_internet
# if_$ENTITIES $ENTITIES_enjoy enjoy_inkflow inkflow_pleas pleas_take take_a a_moment moment_to to_rate rate_it it_again again_in in_the the_app app_store
# if_$ENTITIES $ENTITIES_estim estim_this this_comment comment_useless useless_pleas pleas_leav leav_$ENTITIES $ENTITIES_a a_message
# if_$ENTITIES $ENTITIES_ever ever_chang chang_your your_mind mind_and and_want want_to to_give give_pinger pinger_anoth anoth_try try_$ENTITIES $ENTITIES_can can_alway alway_get get_a a_new new_number
# if_$ENTITIES $ENTITIES_ever ever_chang chang_your your_mind mind_and and_want want_to to_give give_textfre textfre_anoth anoth_try try_$ENTITIES $ENTITIES_can can_alway alway_get get_a a_new new_number
# if_$ENTITIES $ENTITIES_find find_a a_bug bug_or or_anyth anyth_act act_weird weird_pleas pleas_send send_an an_email email_to to_$EMAIL $EMAIL_ID
# if_$ENTITIES $ENTITIES_find find_our our_email email_in in_your your_spam spam_folder folder_pleas pleas_press press_the the_not not_spam spam_button
# if_$ENTITIES $ENTITIES_have have_been been_unabl unabl_to to_find find_or or_qualifi qualifi_for for_the the_perfect perfect_card card_pleas pleas_visit visit_below below_for for_more more_results
# if_$ENTITIES $ENTITIES_need need_assistance assistance_write write_to to_$EMAIL $EMAIL_ID
# if_$ENTITIES $ENTITIES_smoke smoke_use use_alcohol alcohol_or or_take take_illeg illeg_drugs drugs_so so_doe doe_your your_unborn unborn_baby
# if_$ENTITIES $ENTITIES_use use_pinger pinger_to to_text text_and and_call call_peopl peopl_who who_are are_not not_use use_pinger pinger_$ENTITIES $ENTITIES_might might_want want_to to_keep keep_your your_pinger pinger_number number_$NUM $NUM_$NUM $NUM_$NUM $NUM_active
# if_$ENTITIES $ENTITIES_use use_textfre textfre_to to_text text_and and_call call_peopl peopl_who who_are are_not not_use use_textfre textfre_or or_pinger pinger_$ENTITIES $ENTITIES_might might_want want_to to_keep keep_your your_textfre textfre_number number_$NUM $NUM_$NUM $NUM_$NUM $NUM_active
# if_$ENTITIES $ENTITIES_use use_textfre textfre_to to_text text_and and_call call_peopl peopl_who who_are are_not not_use use_textfre textfre_or or_pinger pinger_$ENTITIES $ENTITIES_might might_want want_to to_keep keep_your your_textfre textfre_number number_$NUM $NUM_$NUM $NUM_$NUM $NUM_active
# if_$ENTITIES $ENTITIES_want want_to to_get get_$ENTITIES $ENTITIES_$ENTITIES $ENTITIES_back back_on on_air air_just just_click click_on on_the the_icon icon_again
# if_$ENTITIES $ENTITIES_want want_to to_learn learn_more more_about about_our our_product product_visit visit_mobile mobile_intersog intersog_com
# if_$ENTITIES $ENTITIES_want want_to to_make make_adjustments adjustments_just just_launch launch_the the_m m_dot dot_app app_to to_edit edit_your your_site
# if_$ENTITIES $ENTITIES_want want_to to_make make_more more_than than_$ENTITIES $ENTITIES_know know_what what_to to_do do_with
# if_$ENTITIES $ENTITIES_want want_to to_resend resend_your your_commands commands_send send_$ENTITIES $ENTITIES_to to_$EMAIL $EMAIL_ID
# ...
# per_our_convers our_convers_last convers_last_night last_night_can night_can_$ENTITIES can_$ENTITIES_take $ENTITIES_take_a take_a_look a_look_at look_at_my at_my_list my_list_of list_of_countri of_countri_product countri_product_approv product_approv_and approv_and_let and_let_$ENTITIES let_$ENTITIES_know $ENTITIES_know_if know_if_there if_there_are there_are_ani are_ani_updat ani_updat_to updat_to_the to_the_information
# pleas_join_$ENTITIES join_$ENTITIES_in $ENTITIES_in_wish in_wish_carolyn wish_carolyn_the carolyn_the_veri the_veri_best veri_best_in best_in_$ENTITIES in_$ENTITIES_new $ENTITIES_new_venture
# rich_tell_$ENTITIES tell_$ENTITIES_this $ENTITIES_this_meet this_meet_is meet_is_work is_work_related
# set_up_a up_a_quick a_quick_$NUM quick_$NUM_minut $NUM_minut_meet minut_meet_with meet_with_lon with_lon_and lon_and_laura and_laura_scott laura_scott_with scott_with_respect with_respect_to respect_to_the to_the_incom the_incom_statement
# sinc_i_v i_v_had v_had_to had_to_miss to_miss_the miss_the_first the_first_$NUM first_$NUM_meet $NUM_meet_due meet_due_to due_to_travel to_travel_is travel_is_it is_it_possibl it_possibl_for possibl_for_$ENTITIES for_$ENTITIES_to $ENTITIES_to_drop to_drop_off drop_off_my off_my_check my_check_and check_and_pick and_pick_up pick_up_ani up_ani_materials
# sorri_to_have to_have_miss have_miss_$ENTITIES miss_$ENTITIES_at $ENTITIES_at_the at_the_investor the_investor_present investor_present_last present_last_week last_week_if week_if_$ENTITIES if_$ENTITIES_or $ENTITIES_or_beau or_beau_want beau_want_ani want_ani_of ani_of_the of_the_slide the_slide_pleas slide_pleas_let pleas_let_$ENTITIES let_$ENTITIES_know $ENTITIES_know_and know_and_we and_we_will we_will_forward will_forward_$ENTITIES
# we_will_have will_have_anoth have_anoth_draw anoth_draw_earli draw_earli_next earli_next_week next_week_so week_so_pleas so_pleas_logon pleas_logon_now logon_now_to now_to_unitedway to_unitedway_enron unitedway_enron_com
# when_$ENTITIES_arriv $ENTITIES_arriv_$day arriv_$day_can $day_can_$ENTITIES can_$ENTITIES_let $ENTITIES_let_$ENTITIES let_$ENTITIES_know $ENTITIES_know_how know_how_long how_long_it long_it_will it_will_take will_take_$ENTITIES take_$ENTITIES_to $ENTITIES_to_have to_have_that have_that_sort that_sort_working
# would_$ENTITIES_like $ENTITIES_like_to like_to_set to_set_up set_up_this up_this_meet this_meet_or meet_or_would or_would_$ENTITIES would_$ENTITIES_like $ENTITIES_like_$ENTITIES like_$ENTITIES_to
# $ENTITIES_can_send can_send_$ENTITIES send_$ENTITIES_an $ENTITIES_an_e an_e_mail e_mail_messag mail_messag_and messag_and_my and_my_secretari my_secretari_will secretari_will_contact will_contact_to contact_to_confirm to_confirm_the confirm_the_date the_date_and date_and_place and_place_of place_of_the of_the_meeting
# $ENTITIES_$month_depart $month_depart_on depart_on_$day on_$day_to $day_to_$days to_$days_between $days_between_januari between_januari_$NUM januari_$NUM_and $NUM_and_januari and_januari_$NUM januari_$NUM_$NUM
# $ENTITIES_will_meet will_meet_with meet_with_more with_more_than more_than_$NUM than_$NUM_senior $NUM_senior_power senior_power_industri power_industri_develop industri_develop_and develop_and_advisor and_advisor_for advisor_for_the for_the_most the_most_in most_in_depth in_depth_look depth_look_at look_at_na at_na_power na_power_market power_market_avail market_avail_to avail_to_$ENTITIES
# also_pleas_strong pleas_strong_consid strong_consid_have consid_have_the have_the_board the_board_meet board_meet_on meet_on_$day on_$day_$times $day_$times_in $times_in_lieu in_lieu_of lieu_of_the of_the_golf the_golf_outing
# can_we_wait we_wait_until wait_until_$day until_$day_to $day_to_send to_send_out
# can_$ENTITIES_pleas $ENTITIES_pleas_print pleas_print_$ENTITIES print_$ENTITIES_$NUM $ENTITIES_$NUM_color $NUM_color_copi color_copi_of copi_of_these of_these_report these_report_just report_just_this just_this_week
# can_$ENTITIES_send $ENTITIES_send_$ENTITIES send_$ENTITIES_a $ENTITIES_a_copi a_copi_by copi_by_$day
# could_$ENTITIES_call $ENTITIES_call_bill call_bill_and bill_and_discuss
# could_$ENTITIES_check $ENTITIES_check_with check_with_steve with_steve_and steve_and_his and_his_wife his_wife_for wife_for_their for_their_avail their_avail_on avail_on_$day
# could_$ENTITIES_let $ENTITIES_let_$ENTITIES let_$ENTITIES_know $ENTITIES_know_if know_if_enron if_enron_would enron_would_be would_be_interest be_interest_in interest_in_sponsor in_sponsor_a sponsor_a_team a_team_next team_next_semester next_semester_and semester_and_who and_who_my who_my_point my_point_of point_of_contact of_contact_should contact_should_be should_be_in be_in_the in_the_event the_event_that event_that_$ENTITIES that_$ENTITIES_would $ENTITIES_would_like would_like_to like_to_participate
# could_$ENTITIES_pleas $ENTITIES_pleas_provid pleas_provid_$ENTITIES provid_$ENTITIES_with $ENTITIES_with_the with_the_exact the_exact_address exact_address_so address_so_that so_that_i that_i_can i_can_send can_send_this send_this_overnight this_overnight_to overnight_to_your to_your_attention
# get_$ENTITIES_the $ENTITIES_the_roll the_roll_off roll_off_schedul off_schedul_for schedul_for_cnr for_cnr_over cnr_over_the over_the_next the_next_coupl next_coupl_of coupl_of_years
# if_the_agreement the_agreement_meet agreement_meet_with meet_with_your with_your_approval your_approval_pleas approval_pleas_return pleas_return_a return_a_copi a_copi_to copi_to_$ENTITIES to_$ENTITIES_via $ENTITIES_via_fax via_fax_no
# if_the_enclos the_enclos_meet enclos_meet_with meet_with_your with_your_approval your_approval_pleas approval_pleas_have pleas_have_the have_the_agreement the_agreement_execut agreement_execut_by execut_by_an by_an_author an_author_offic author_offic_of offic_of_webmethod of_webmethod_and webmethod_and_return and_return_the return_the_copi the_copi_to copi_to_$ENTITIES to_$ENTITIES_for $ENTITIES_for_execut for_execut_by execut_by_enron
# if_$ENTITIES_are $ENTITIES_are_interest are_interest_in interest_in_be in_be_a be_a_team a_team_leader team_leader_pleas leader_pleas_contact pleas_contact_one contact_one_of one_of_the of_the_follow the_follow_peopl follow_peopl_immedi peopl_immedi_so immedi_so_that so_that_$ENTITIES that_$ENTITIES_$month $ENTITIES_$month_be $month_be_includ be_includ_in includ_in_the in_the_first the_first_import first_import_and import_and_inform and_inform_train inform_train_session train_session_take session_take_place take_place_this place_this_week
# if_$ENTITIES_don $ENTITIES_don_t don_t_get t_get_it get_it_tomorrow it_tomorrow_let tomorrow_let_$ENTITIES let_$ENTITIES_know
# jan_can_$ENTITIES can_$ENTITIES_let $ENTITIES_let_christian let_christian_know christian_know_that know_that_i that_i_will i_will_not will_not_be not_be_in be_in_the in_the_offic the_offic_on offic_on_$day
# let_$ENTITIES_know $ENTITIES_know_when know_when_a when_a_conveni a_conveni_time conveni_time_would time_would_be would_be_for be_for_$ENTITIES for_$ENTITIES_$monthb $ENTITIES_$monthb_$day $monthb_$day_sometime
# note_if_$ENTITIES if_$ENTITIES_have $ENTITIES_have_alreadi have_alreadi_regist alreadi_regist_for regist_for_this for_this_conference this_conference_or conference_or_would or_would_like would_like_to like_to_be to_be_taken be_taken_off taken_off_the off_the_email the_email_list email_list_pleas list_pleas_repli pleas_repli_to repli_to_this to_this_email this_email_and email_and_type and_type_in type_in_unsubscrib in_unsubscrib_in unsubscrib_in_the in_the_subject the_subject_line
# pleas_advis_if advis_if_this if_this_work this_work_with work_with_your with_your_schedule
# pleas_call_ben call_ben_jacobi ben_jacobi_and jacobi_and_see and_see_if see_if_we if_we_can we_can_push can_push_our push_our_meet our_meet_to meet_to_$NUM
# pleas_call_cathi call_cathi_at cathi_at_$NUM at_$NUM_and $NUM_and_get and_get_on get_on_my on_my_calendar my_calendar_for calendar_for_a for_a_$NUM a_$NUM_hour $NUM_hour_update
# pleas_call_john call_john_keffer john_keffer_and keffer_and_re and_re_schedul re_schedul_$day schedul_$day_lunch $day_lunch_two lunch_two_meet two_meet_have meet_have_come have_come_up
# pleas_call_lee call_lee_johnson lee_johnson_and johnson_and_tell and_tell_$ENTITIES tell_$ENTITIES_that $ENTITIES_that_one that_one_of one_of_our of_our_develop our_develop_lawyers develop_lawyers_roger lawyers_roger_balog roger_balog_would balog_would_like would_like_$NUM like_$NUM_ticket $NUM_ticket_for ticket_for_$day
# pleas_call_stan call_stan_at stan_at_$NUM at_$NUM_$NUM $NUM_$NUM_$NUM $NUM_$NUM_and $NUM_and_discuss and_discuss_with discuss_with_$ENTITIES
# pleas_call_my call_my_assist my_assist_to assist_to_set to_set_up set_up_an up_an_appoint an_appoint_for appoint_for_earli for_earli_$day
# pleas_confirm_your confirm_your_particip your_particip_as particip_as_soon as_soon_as soon_as_possible as_possible_prefer possible_prefer_by prefer_by_the by_the_end the_end_of end_of_this of_this_week this_week_or week_or_the or_the_begin the_begin_of begin_of_next of_next_week next_week_as week_as_speak as_speak_posit speak_posit_will posit_will_fill will_fill_quickly
# pleas_contact_cathi contact_cathi_phillip cathi_phillip_via phillip_via_e via_e_mail e_mail_or mail_or_call or_call_$NUM call_$NUM_$NUM $NUM_$NUM_$NUM $NUM_$NUM_to $NUM_to_schedul to_schedul_time schedul_time_with time_with_mike
# pleas_contact_$ENTITIES contact_$ENTITIES_at $ENTITIES_at_your at_your_earliest your_earliest_conveni earliest_conveni_by conveni_by_email by_email_or email_or_phone or_phone_at phone_at_the at_the_number the_number_below number_below_to below_to_discuss to_discuss_thing discuss_thing_if thing_if_$ENTITIES if_$ENTITIES_think $ENTITIES_think_it think_it_would it_would_be would_be_a be_a_possibl a_possibl_or possibl_or_if or_if_$ENTITIES if_$ENTITIES_would $ENTITIES_would_like would_like_more like_more_inform more_inform_on inform_on_the on_the_context the_context_of context_of_the of_the_work the_work_and work_and_subject and_subject_matter subject_matter_in matter_in_aspentech in_aspentech_core aspentech_core_businesses
# pleas_continu_to continu_to_let to_let_$ENTITIES let_$ENTITIES_know $ENTITIES_know_about know_about_futur about_futur_meetings
# pleas_email_$ENTITIES email_$ENTITIES_a $ENTITIES_a_brief a_brief_overview brief_overview_of overview_of_what of_what_these what_these_document these_document_are document_are_how are_how_they how_they_fit they_fit_into fit_into_the into_the_overal the_overal_picture overal_picture_and picture_and_the and_the_issu the_issu_which issu_which_need which_need_the need_the_most the_most_scrutiny
# pleas_email_$ENTITIES email_$ENTITIES_with $ENTITIES_with_the with_the_specif the_specif_perform specif_perform_languag perform_languag_$ENTITIES languag_$ENTITIES_want $ENTITIES_want_to want_to_add to_add_to add_to_meet to_meet_their meet_their_request
# pleas_email_the email_the_session the_session_descript session_descript_by descript_by_$day by_$day_novemb $day_novemb_$NUM
# pleas_explain_how explain_how_the how_the_loss the_loss_of loss_of_buyer of_buyer_market buyer_market_could market_could_be could_be_due be_due_to due_to_an to_an_event an_event_of event_of_forc of_forc_majeur forc_majeur_and majeur_and_whi and_whi_the whi_the_buyer the_buyer_should buyer_should_not should_not_be not_be_requir be_requir_to requir_to_find to_find_a find_a_new a_new_market new_market_dure market_dure_such dure_such_period
# pleas_handl_at handl_at_the at_the_audit the_audit_committe audit_committe_meeting
# pleas_indic_below indic_below_whether below_whether_or whether_or_not or_not_$ENTITIES not_$ENTITIES_plan $ENTITIES_plan_to plan_to_attend to_attend_this attend_this_meet this_meet_and meet_and_through and_through_what through_what_medium
# pleas_keep_this keep_this_news this_news_to news_to_yourself to_yourself_until yourself_until_next until_next_week
# pleas_let_$ENTITIES let_$ENTITIES_know $ENTITIES_know_by know_by_tomorrow by_tomorrow_morn tomorrow_morn_if morn_if_$ENTITIES if_$ENTITIES_have $ENTITIES_have_ani have_ani_comments
# pleas_let_$ENTITIES let_$ENTITIES_know $ENTITIES_know_when know_when_$ENTITIES when_$ENTITIES_are $ENTITIES_are_readi are_readi_to readi_to_discuss
# pleas_let_$ENTITIES let_$ENTITIES_know $ENTITIES_know_if know_if_$ENTITIES if_$ENTITIES_would $ENTITIES_would_like would_like_to like_to_attend to_attend_and attend_and_i and_i_will i_will_see will_see_that see_that_$ENTITIES that_$ENTITIES_receiv $ENTITIES_receiv_a receiv_a_formal a_formal_invitation
# pleas_protect_$day protect_$day_$times $day_$times_$month $times_$month_10th $month_10th_for 10th_for_$ENTITIES
# pleas_remov_$ENTITIES remov_$ENTITIES_from $ENTITIES_from_your from_your_email your_email_list email_list_for list_for_further for_further_htc further_htc_events
# pleas_review_the review_the_attach the_attach_document attach_document_to document_to_see to_see_if see_if_it if_it_reflect it_reflect_the reflect_the_matter the_matter_we matter_we_discussed
# pleas_review_to review_to_see to_see_if see_if_i if_i_have i_have_made have_made_all made_all_of all_of_the of_the_chang the_chang_$ENTITIES chang_$ENTITIES_discuss $ENTITIES_discuss_with discuss_with_$ENTITIES
# pleas_send_to send_to_jeff to_jeff_for jeff_for_final for_final_review final_review_and review_and_one and_one_more one_more_pass more_pass_thru pass_thru_the thru_the_busi the_busi_unit busi_unit_on unit_on_$day
# pleas_set_up set_up_a up_a_confer a_confer_call confer_call_for call_for_tomorrow for_tomorrow_$NUM tomorrow_$NUM_houston $NUM_houston_time houston_time_and time_and_advis and_advis_the advis_the_follow the_follow_of follow_of_the of_the_details
# pleas_tell_mike tell_mike_that mike_that_i that_i_m i_m_on m_on_a on_a_confer a_confer_call confer_call_but call_but_can but_can_step can_step_out step_out_if out_if_he if_he_want he_want_to want_to_come to_come_up
# please_let_$ENTITIES let_$ENTITIES_know $ENTITIES_know_if know_if_$ENTITIES if_$ENTITIES_want $ENTITIES_want_somebodi want_somebodi_from somebodi_from_your from_your_organ your_organ_at organ_at_the at_the_meeting
# please_let_$ENTITIES let_$ENTITIES_know $ENTITIES_know_the know_the_detail the_detail_of detail_of_the of_the_dinners
# please_put_it put_it_on it_on_my on_my_calendar
# please_put_it put_it_on it_on_my on_my_schedule
# please_put_on put_on_my on_my_calendar
# please_put_on put_on_my on_my_schedule
# please_regist_$ENTITIES regist_$ENTITIES_for $ENTITIES_for_this for_this_conference
# please_set_up set_up_a up_a_meet a_meet_with meet_with_$ENTITIES with_$ENTITIES_nelson $ENTITIES_nelson_and nelson_and_vasant
# shirley_please_put please_put_it put_it_on it_on_my on_my_calendar
# shirley_please_put please_put_on put_on_my on_my_schedule
# tana_can_$ENTITIES can_$ENTITIES_fax $ENTITIES_fax_$ENTITIES fax_$ENTITIES_the $ENTITIES_the_final the_final_execut final_execut_copi execut_copi_of copi_of_the of_the_follow the_follow_agreement follow_agreement_we agreement_we_did we_did_this did_this_week
# whi_don_t don_t_$ENTITIES t_$ENTITIES_tri $ENTITIES_tri_feed tri_feed_$ENTITIES feed_$ENTITIES_again $ENTITIES_again_at again_at_night
# would_$ENTITIES_allow $ENTITIES_allow_$ENTITIES allow_$ENTITIES_to $ENTITIES_to_get to_get_$ENTITIES get_$ENTITIES_comment $ENTITIES_comment_by comment_by_$NUM by_$NUM_00am $NUM_00am_tomorrow
# could_$ENTITIES_call $ENTITIES_call_$ENTITIES call_$ENTITIES_on $ENTITIES_on_$day on_$day_with $day_with_further with_further_inform further_inform_on inform_on_our on_our_panel
# pleas_call_$ENTITIES call_$ENTITIES_at $ENTITIES_at_your at_your_conveni your_conveni_to conveni_to_discuss
# pleas_call_the call_the_list the_list_around list_around_$NUM around_$NUM_to $NUM_to_see to_see_if see_if_peopl if_peopl_are peopl_are_available
# pleas_give_$ENTITIES give_$ENTITIES_a $ENTITIES_a_call a_call_tomorrow call_tomorrow_to tomorrow_to_discuss to_discuss_briefly
# pleas_review_the review_the_below the_below_and below_and_let and_let_discuss let_discuss_if discuss_if_this if_this_realli this_realli_works

# %%
#SVM C value for bi-grams
best_c={}
for increment in range(1000, 15000, 100):
    svm=SVC(C=increment, kernel = 'rbf')
    svm.fit(x_train1, y_train1)
    tr_ac, te_ac = svm.score(x_train1, y_train1), svm.score(x_test1, y_test1)
    best_c[str(increment)]=te_ac
import operator
print " Max C value : ",max(best_c.iteritems(),key=operator.itemgetter(1))[0]
# Out:
#  Max C value :  14600

# %%
#SVM C value for tri-grams
best_tri_c={}
for increment in range(10000, 30000, 100):
    svm=SVC(C=increment, kernel = 'rbf')
    svm.fit(x_train1, y_train1)
    tr_ac, te_ac = svm.score(x_train1, y_train1), svm.score(x_test1, y_test1)
    best_tri_c[str(increment)]=te_ac
import operator
print " Max C value trigrams : ",max(best_tri_c.iteritems(),key=operator.itemgetter(1))[0]
# Out:
#  Max C value trigrams :  23200

# %%
#bi-gram SVM max value as C = 14600
svm=SVC(C=14600, kernel='rbf')
svm.fit(x_train1, y_train1)
print "SVM Classification for Bi-Grams : "
print "Training accuracy : ",svm.score(x_train1, y_train1)
print "Testing accuracy : ",svm.score(x_test1, y_test1)

#tri-gram SVM max value as C = 23200
svm=SVC(C=23200, kernel='rbf')
svm.fit(x_train2, y_train2)
print "\nSVM Classification for Tri-Grams : "
print "Training accuracy : ",svm.score(x_train2, y_train2)
print "Testing accuracy : ",svm.score(x_test2, y_test2)
# Out:
# SVM Classification for Bi-Grams :
# Training accuracy :  0.9797172710510141
# Testing accuracy :  0.7827956989247312
#
# SVM Classification for Tri-Grams :
# Training accuracy :  0.9929317762753535
# Testing accuracy :  0.739068100358423
